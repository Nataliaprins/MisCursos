# %% [markdown]
# # Optimización Robusta de Portafolios
#
# Este cuaderno está en preparación.
#
# Próximamente se incluirán ejemplos de optimización robusta bajo incertidumbre en retornos y covarianzas.
