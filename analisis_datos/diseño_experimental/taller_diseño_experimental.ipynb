# %% [markdown]
# # Taller: Diseño Completamente Aleatorizado
#
# **Tema:** Diseño Completamente Aleatorizado (DCA), ANOVA y Comparaciones Múltiples
#
# ---
#
# ## Contexto empresarial
#
# Una empresa de retail desea **identificar cuál estrategia de marketing genera mayores ventas**.
# Para ello diseñó un experimento en el que se asignaron aleatoriamente cuatro estrategias a un conjunto de clientes y se registraron las ventas generadas (en miles de pesos).
#
# Las estrategias evaluadas son:
#
# | Tratamiento | Descripción |
# |-------------|-------------|
# | Email Marketing | Envío de correos personalizados con ofertas |
# | Publicidad Redes | Pauta paga en redes sociales |
# | Influencers | Colaboración con creadores de contenido |
# | Descuentos | Cupones y promociones directas |
#
# > **Nota:** Si bien la empresa reconoce que las ciudades pueden tener comportamientos de consumo diferentes, en este experimento se asumió que las unidades experimentales son homogéneas. Al final del taller reflexionarás sobre si esta suposición es adecuada.
#
# ---
# **Descarga la base de datos del estudio:**  [BD_Marketing](diseno_bloques_aleatorizados.csv)
#
#
#
# ## Objetivos del taller
#
# 1. Identificar correctamente los elementos del diseño experimental.
# 2. Realizar un análisis exploratorio de los datos.
# 3. Verificar los supuestos del modelo ANOVA.
# 4. Aplicar e interpretar el ANOVA de una vía.
# 5. Aplicar comparaciones múltiples para identificar qué estrategia es superior.
# 6. Formular recomendaciones empresariales basadas en los resultados.

# %% [markdown]
# ---
# ## Librerías y carga de datos
#
# Ejecuta la siguiente celda para importar las librerías necesarias y cargar la base de datos. Asegúrate de que la ruta al archivo sea la correcta.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from statsmodels.formula.api import ols
import statsmodels.api as sm
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['axes.titlesize'] = 13
sns.set_theme(style='whitegrid', palette='Set2')

# Carga de datos
# df = pd.read_csv('diseno_completamente_aleatorizado.csv')
# print(f'Filas: {df.shape[0]}  |  Columnas: {df.shape[1]}')
# df.head(10)

# %% [markdown]
# ---
# ## Parte 1 — Planeación del experimento
#
# ### Pregunta 1.1
#
# Identifica cada uno de los elementos del diseño experimental a partir del contexto empresarial descrito. Completa la siguiente tabla en una celda Markdown:
#
# | Elemento | Tu respuesta |
# |----------|--------------|
# | Objetivo del experimento | |
# | Variable independiente (factor) | |
# | Niveles del factor | |
# | Variable dependiente (respuesta) | |
# | Unidad experimental | |
# | Número de réplicas por tratamiento | |
# | Tipo de diseño utilizado | |

# %% [markdown]
# ### Pregunta 1.2
#
# Escribe formalmente las hipótesis estadísticas que se van a contrastar en este experimento.
# Usa la notación matemática apropiada e indica qué significa cada símbolo en el contexto del problema.

# %% [markdown]
# **✏️ Escribe tu respuesta aquí:**
#
# $$H_0: $$
#
# $$H_1: $$
#
# Donde:

# %% [markdown]
# ### Pregunta 1.3
#
# ¿Por qué es importante la aleatorización en este experimento?
# Menciona al menos dos fuentes de variación que podrían introducir sesgo si los tratamientos no se asignan aleatoriamente a los clientes.

# %% [markdown]
# **✏️ Escribe tu respuesta aquí:**

# %% [markdown]
# ---
# ## Parte 2 — Análisis exploratorio de datos
#
# ### Pregunta 2.1
#
# Calcula las estadísticas descriptivas (n, media, desviación estándar, mínimo y máximo) de las ventas para **cada estrategia de marketing**.
# A partir de los resultados, ¿qué estrategia parece generar mayores ventas en promedio?

# %% [markdown]
# **✏️ Interpretación:** *(escribe tu análisis aquí)*

# %% [markdown]
# ### Pregunta 2.2
#
# Genera un **boxplot** que muestre la distribución de las ventas para cada estrategia de marketing.
# Superpón los puntos individuales al gráfico (strip plot).
# Asegúrate de incluir título, etiquetas de ejes y una leyenda o paleta de colores diferenciada.

# %% [markdown]
# **✏️ Interpretación:** *(escribe tu análisis aquí)*
# ¿Observas diferencias visibles entre los grupos? ¿Algún grupo presenta mayor dispersión o valores atípicos?

# %% [markdown]
# ### Pregunta 2.3
#
# Genera un gráfico de barras con las **ventas promedio por estrategia** e incluye barras de error que representen la desviación estándar.
# ¿Las diferencias visuales entre promedios son suficientes para concluir que existe una estrategia superior? Justifica.

# %% [markdown]
# ---
# ## Parte 3 — Verificación de supuestos del ANOVA
#
# Antes de aplicar el ANOVA es necesario verificar que los datos cumplen los supuestos del modelo:
# 1. **Normalidad** de los residuos
# 2. **Homogeneidad de varianzas** entre grupos
# 3. **Independencia** de las observaciones (garantizada por el diseño)
#
# ### Pregunta 3.1 — Normalidad
#
# Ajusta el modelo lineal (`ols`) y obtén los residuos.
# Genera los siguientes gráficos diagnósticos:
# - Histograma de residuos
# - Q-Q plot
#
# Aplica la **prueba de Shapiro-Wilk** e interpreta el resultado a un nivel de significancia del 5%.

# %% [markdown]
# **✏️ Interpretación:**
# - Estadístico W = , p-valor =
# - Conclusión sobre el supuesto de normalidad:

# %% [markdown]
# ### Pregunta 3.2 — Homogeneidad de varianzas
#
# Aplica la **prueba de Levene** para evaluar si las varianzas de ventas son iguales entre las cuatro estrategias.
# Complementa el análisis con un gráfico de **residuos vs. valores ajustados**.

# %% [markdown]
# **✏️ Interpretación:**
# - Estadístico Levene = , p-valor =
# - Conclusión sobre el supuesto de homogeneidad de varianzas:

# %% [markdown]
# ### Pregunta 3.3
#
# Con base en los resultados de las pruebas de supuestos, ¿es válido aplicar el ANOVA paramétrico en este caso?
# ¿Qué alternativa no paramétrica podrías usar si los supuestos no se cumplen?

# %% [markdown]
# ---
# ## Parte 4 — Análisis de Varianza (ANOVA)
#
# ### Pregunta 4.1
#
# Obtén la **tabla ANOVA** del modelo ajustado e identifica cada uno de sus componentes.
# Completa la siguiente tabla con los valores calculados:
#
# | Fuente | GL | SS | MS | F calculado | p-valor |
# |--------|----|----|-----|-------------|--------|
# | Tratamiento | | | | | |
# | Error | | | | | |
# | Total | | | | | |

# %% [markdown]
# **✏️ Completa la tabla ANOVA anterior con los valores obtenidos:**

# %% [markdown]
# ### Pregunta 4.2
#
# Interpreta el resultado del ANOVA con un nivel de significancia α = 0.05.
# Responde:
#
# 1. ¿Cuál es la conclusión estadística respecto a las hipótesis planteadas en 1.2?
# 2. ¿Qué porcentaje de la variabilidad total en las ventas es explicado por la estrategia de marketing? (Calcula e interpreta el R²)
# 3. ¿El ANOVA permite saber *cuál* estrategia es la mejor? ¿Por qué?

# %% [markdown]
# ---
# ## Parte 5 — Comparaciones múltiples
#
# ### Pregunta 5.1 — Inflación del error de Tipo I
#
# Si quisieras comparar las 4 estrategias usando pruebas t individuales (sin corrección), ¿cuántas comparaciones necesitarías realizar?
# Calcula la **tasa de error familiar (FWER)** para ese número de comparaciones con α = 0.05.
# ¿Por qué este enfoque es problemático?

# %% [markdown]
# ### Pregunta 5.2 — Prueba de Tukey HSD
#
# Aplica la **prueba de Tukey HSD** (α = 0.05) para comparar todas las estrategias de marketing entre sí.
# Presenta la tabla de resultados completa.

# %% [markdown]
# ### Pregunta 5.3 — Interpretación de Tukey
#
# A partir de los resultados de Tukey, responde:
#
# 1. ¿Qué pares de estrategias presentan diferencias estadísticamente significativas?
# 2. ¿Cuál es la estrategia que genera ventas significativamente mayores respecto a las demás?
# 3. ¿Existe algún par de estrategias que **no** presente diferencia significativa? ¿Qué implica esto para la empresa?

# %% [markdown]
# ### Pregunta 5.4 — Visualización de comparaciones múltiples
#
# Genera el gráfico de intervalos de confianza de la prueba de Tukey.
# ¿Cómo se lee este gráfico? ¿Qué indica cuando los intervalos de confianza de dos estrategias no se solapan?

# %% [markdown]
# ---
# ## Parte 6 — Reflexión crítica y recomendaciones
#
# ### Pregunta 6.1 — Limitaciones del DCA
#
# El contexto indica que **las ciudades tienen comportamientos de consumo diferentes**.
# Sin embargo, el diseño utilizado es un DCA que no controla este efecto.
#
# 1. ¿Qué problema estadístico puede generar ignorar el efecto ciudad en el análisis?
# 2. ¿Qué tipo de diseño experimental sería más adecuado si se quiere controlar el efecto de las ciudades? Explica brevemente su estructura.
# 3. ¿Cómo cambiaría el modelo estadístico si incorporas la ciudad como factor de bloqueo?

# %% [markdown]
# ### Pregunta 6.2 — Recomendación empresarial
#
# Con base en todos los resultados obtenidos (análisis exploratorio, ANOVA y comparaciones múltiples), redacta un **párrafo de recomendación** dirigido a la gerencia de marketing de la empresa.
#
# Tu recomendación debe:
# - Indicar qué estrategia se recomienda adoptar y por qué.
# - Mencionar las limitaciones del análisis realizado.
# - Sugerir al menos un paso adicional que la empresa debería considerar antes de tomar la decisión final.
